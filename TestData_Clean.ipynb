# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
test = pd.read_excel('/content/drive/MyDrive/Data/05 Input Data/Prediction of Placement Status Data/02 Test Data.xlsx')
test.head()
# Out:
#    First Name            Email ID  Quantity  Price Tier      Ticket Type  \
# 0      Sahil        sahil@xyz.com         1         NaN  Hello ML and DL
# 1     Amrita       amrita@xyz.com         1         NaN  Hello ML and DL
# 2       Mamta       mamta@xyz.com         1         NaN  Hello ML and DL
# 3  Bhagyashri  bhagyashri@xyz.com         1         NaN  Hello ML and DL
# 4   Divyanshu   divyanshu@xyz.com         1         NaN  Hello ML and DL
#
#      Attendee #  Group  Order Type Currency  Total Paid  ...  Attendee Status  \
# 0  2.293940e+09    NaN  Free Order      USD           0  ...        Attending
# 1  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 2  2.293941e+09    NaN  Free Order      USD           0  ...        Attending
# 3  2.293946e+09    NaN  Free Order      USD           0  ...        Attending
# 4  2.293956e+09    NaN  Free Order      USD           0  ...        Attending
#
#                                      College Name  \
# ...

# %%
test.drop(test.columns[[2,3,5,6,7,8,9,10,11,12,13,15,16,18]],axis = 1,inplace = True)

# %%
test.isna().sum()
# Out:
# First Name             0
# Email ID               0
# Ticket Type            0
# College Name           1
# Designation            0
# CGPA                   0
# Speaking Skills        0
# ML Knowledge           0
# Placement Status    3796
# dtype: int64

# %%
test.dropna(subset=['College Name'],inplace = True)
test.isna().sum()
# Out:
# First Name             0
# Email ID               0
# Ticket Type            0
# College Name           0
# Designation            0
# CGPA                   0
# Speaking Skills        0
# ML Knowledge           0
# Placement Status    3795
# dtype: int64

# %%
categorical_values=['First Name','Email ID','Ticket Type','College Name','Designation','Placement Status']

# %%
test[categorical_values].nunique()
# Out:
# First Name          2556
# Email ID            2320
# Ticket Type           14
# College Name          54
# Designation           49
# Placement Status       0
# dtype: int64

# %%
test_clean = test.drop(['First Name','Email ID','College Name','Designation','Ticket Type'],axis=1)

# %%
test_clean.head()
# Out:
#    CGPA  Speaking Skills  ML Knowledge  Placement Status
# 0   7.8                3             3               NaN
# 1   9.1                3             3               NaN
# 2   6.9                2             2               NaN
# 3   8.4                4             4               NaN
# 4   6.7                5             5               NaN

# %%
test_clean = pd.get_dummies(test_clean)

# %%
test_clean.head()
# Out:
#    CGPA  Speaking Skills  ML Knowledge  Placement Status
# 0   7.8                3             3               NaN
# 1   9.1                3             3               NaN
# 2   6.9                2             2               NaN
# 3   8.4                4             4               NaN
# 4   6.7                5             5               NaN

# %%
test_clean.to_excel('/content/drive/MyDrive/Data/Test_Cleaned.xlsx',index=False)
